# %% [markdown]
# ñlñlñl

# %%
import cv2 # opencv
import numpy as np
import matplotlib.pyplot as plt
#cargar una imagen 

imagen =cv2.imread('maquiavelo.jpg')
imgrgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

plt.title('primera imagen')
plt.imshow(imgrgb)
plt.show()

# %% [markdown]
# Ejercicio 1

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

luci= cv2.imread('luci.jpg')
lucirgb= cv2.cvtColor(luci, cv2.COLOR_BGR2RGB)

plt.title('luci el gato')
plt.imshow(lucirgb)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[8,5]
img=cv2.imread('1.jpg')
plt.imshow(img)
plt.show()
print('Tamaño de imagen y canales:',img.shape)

# %%
import cv2
import matplotlib.pyplot as ptl
import numpy as np

plt.rcParams['figure.figsize']=[20,5]
img= cv2.imread('luci.jpg')
plt.imshow(img)
plt.show()
print('medidas de imagen y canales:', img.shape)
# Out:
# medidas de imagen y canales: (1200, 1200, 3)

# %%
import cv2
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 5]  # Tamaño de la figura

# Cargar la imagen en formato BGR
img = cv2.imread('maquiavelo.jpg', cv2.IMREAD_COLOR)

# Mostrar la imagen original en RGB
plt.subplot(141)
plt.title('Imagen Original')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# Mostrar canal Azul
plt.subplot(142)
plt.imshow(img[:, :, 0], cmap='gray')  # Mostrar en escala de grises
plt.title('Canal Azul')

# Mostrar canal Verde
plt.subplot(143)
plt.imshow(img[:, :, 1], cmap='gray')  # Mostrar en escala de grises
plt.title('Canal Verde')

# Mostrar canal Rojo
plt.subplot(144)
plt.imshow(img[:, :, 2], cmap='gray')  # Mostrar en escala de grises
plt.title('Canal Rojo')

plt.show()

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np


plt.rcParams['figure.figsize']=[10,5]
tamanio_imagen= 100
R=np.ones((tamanio_imagen, tamanio_imagen))*255
G=np.ones((tamanio_imagen, tamanio_imagen))*128
B=np.ones((tamanio_imagen, tamanio_imagen))*0

img=np.dstack((R,G,B))
img=np.array(img,dtype=int)
plt.figure()
plt.imshow(img)
plt.show()

tamanio2=50
R=np.ones((tamanio2, tamanio2))*189
G=np.ones((tamanio2, tamanio2))*70
B=np.ones((tamanio2, tamanio2))*0

imge=np.dstack((R,G,B))
imge=np.array(imge,dtype=int)
plt.figure()
plt.imshow(imge)
plt.show()

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

maki1= cv2.imread('maquiavelo.jpg', cv2.IMREAD_GRAYSCALE)
img1= maki1.dtype
plt.figure()
plt.imshow(maki1)
plt.show()
print('profundidad de color', img1)
img_16bit=np.uint16(maki1)
imgnueva= img_16bit.dtype
plt.figure()
plt.imshow(img_16bit)
plt.show()
print('profundidad de color', imgnueva)
# Out:
# profundidad de color uint8
# profundidad de color uint16

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
fig, axs= plt.subplots(1,4,figsize=[25,10])
img= cv2.imread('maquiavelo.jpg',cv2.COLOR_BGR2RGB)
hsv=cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
axs[0].imshow(img)
axs[0].set_title('imagen')

fig1= axs[1],plt.imshow(hsv[ .,. ,0], cmap='gray', vmin=0, vmax=179)
# Out:
# Text(0.5, 1.0, 'imagen')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np


plt.rcParams['figure.figsize']=[4,4]
tamanio_imagen= 50
R=np.ones((tamanio_imagen, tamanio_imagen))*0
G=np.ones((tamanio_imagen, tamanio_imagen))*255
B=np.ones((tamanio_imagen, tamanio_imagen))*0

img=np.dstack((R,G,B))
img=np.array(img,dtype=int)
plt.figure()
plt.imshow(img)
plt.show()
fig, axs= plt.subplots(2,2,figsize=[8,8])
plt.subplots_adjust(wspace=0, hspace=0)
axs[0,0].imshow(img)
axs[0,0].set_title('imagen')
R=np.ones((tamanio_imagen, tamanio_imagen))*255
G=np.ones((tamanio_imagen, tamanio_imagen))*0
B=np.ones((tamanio_imagen, tamanio_imagen))*0
img=np.dstack((R,G,B))
img=np.array(img,dtype=int)
axs[1,0].imshow(img)
axs[1,0].set_title('imagen')
R=np.ones((tamanio_imagen, tamanio_imagen))*0
G=np.ones((tamanio_imagen, tamanio_imagen))*0
B=np.ones((tamanio_imagen, tamanio_imagen))*255
img=np.dstack((R,G,B))
img=np.array(img,dtype=int)
axs[1,1].imshow(img)
axs[1,1].set_title('imagen')
R=np.ones((tamanio_imagen, tamanio_imagen))*0
G=np.ones((tamanio_imagen, tamanio_imagen))*0
B=np.ones((tamanio_imagen, tamanio_imagen))*0
img=np.dstack((R,G,B))
img=np.array(img,dtype=int)
axs[0,1].imshow(img)
axs[0,1].set_title('imagen')
# Out:
# Text(0.5, 1.0, 'imagen')

# %% [markdown]
# ECUCACIONESSSSS

# %%
import numpy as np
Imagen = cv2.imread('maquiavelo.jpg')
img= cv2.cvtColor(Imagen, cv2.COLOR_BGR2RGB)
def RGB2HSV(img):
    img = img.astype(np.float32)
    img = img/255.
    new_img = np.zeros_like(img)

    maxChannel = np.argmax(img,axis=2)
    maxValue = np.amax(img,axis=2)
    minChannel = np.argmin(img,axis=2)
    minValue = np.amin(img,axis=2)
    #value 
    new_img[...,2] = maxValue

    #saturation
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if maxValue[i,j]==0:
                new_img[i,j,1] = 0
            elif maxValue[i,j] != 0:
                new_img[i,j,1] = (new_img[i,j,2]-minValue[i,j])/new_img[i,j,2]

    #hue 
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if sum(img[i,j,...])/3 == img[i,j,0]:
                new_img[i,j,0] = 0
            elif maxChannel[i,j] == 0: #R 
                new_img[i,j,0] = 60 * ((img[i,j,1]-img[i,j,2])/(new_img[i,j,2]-minValue[i,j]))
            elif maxChannel[i,j] == 1: #G
                new_img[i,j,0] = 120 + 60 * (img[i,j,2]-img[i,j,0])/(new_img[i,j,2]-minValue[i,j])
            elif maxChannel[i,j] == 2: #B
                new_img[i,j,0] = 240 + 60 * (img[i,j,0]-img[i,j,1])/(new_img[i,j,2]-minValue[i,j])

        bol_ind = new_img[...,0] < 0
        new_img[bol_ind,0]   =  new_img[bol_ind,0] + 360
    return new_img 

hsv_img =  RGB2HSV(img) 
fig, axs = plt.subplots(1,4,figsize=(25,10))
axs[0].imshow(img)
axs[0].set_title('Imagen')
fig_img = axs[1].imshow(hsv_img[...,0],cmap='gray',vmin=0,vmax=360)
fig.colorbar(fig_img, ax=axs[1],shrink=0.3)
axs[1].set_title('Canal Hue')
fig_img = axs[2].imshow(hsv_img[...,1],cmap='gray',vmin=0,vmax=1)
fig.colorbar(fig_img, ax=axs[2],shrink=0.3)
axs[2].set_title('Canal Saturación')
fig_img = axs[3].imshow(hsv_img[...,2],cmap='gray',vmin=0,vmax=1)
fig.colorbar(fig_img, ax=axs[3],shrink=0.3)
axs[3].set_title('Canal Value');

# %%
def HSV2RGB(img):
    new_img = np.zeros_like(img)
    
    C = img[...,2]*img[...,1]
    X = C*(1-abs((img[...,0]/60)%2-1))
    m = img[...,2]-C

    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            h = img[i,j,0]
            if 0 <= h and h < 60:
                new_img[i,j] = C[i,j],X[i,j],0
            elif 60 <= h and h < 120:
                new_img[i,j] = X[i,j],C[i,j],0
            elif 120 <= h and h < 180:
                new_img[i,j] = 0,C[i,j],X[i,j]
            elif 180 <= h and h < 240:
                new_img[i,j] = 0,X[i,j],C[i,j]
            elif 240 <= h and h < 300:
                new_img[i,j] = X[i,j],0,C[i,j]
            elif 300 <= h and h < 360:
                new_img[i,j] = C[i,j],0,X[i,j]
    new_img[...,0] = (new_img[...,0]+m)*255
    new_img[...,1] = (new_img[...,1]+m)*255
    new_img[...,2] = (new_img[...,2]+m)*255
    new_img = new_img.astype(int)
    return new_img 
rgb_img =   HSV2RGB(hsv_img) 
fig, axs = plt.subplots(1,4,figsize=(25,10))

axs[0].imshow(img)
axs[0].set_title('Imagen')


fig_img = axs[1].imshow(rgb_img[...,0],cmap='gray',vmin=0,vmax=255)
fig.colorbar(fig_img, ax=axs[1],shrink=0.3)
axs[1].set_title('Canal Rojo')


fig_img = axs[2].imshow(rgb_img[...,1],cmap='gray',vmin=0,vmax=255)
fig.colorbar(fig_img, ax=axs[2],shrink=0.3)
axs[2].set_title('Canal Verde')


fig_img = axs[3].imshow(rgb_img[...,2],cmap='gray',vmin=0,vmax=255)
fig.colorbar(fig_img, ax=axs[3],shrink=0.3)
axs[3].set_title('Canal Azul');

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_rgb= cv2.cvtColor(cv2.imread('maquiavelo.jpg', cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB)
img_hsv= cv2.cvtColor(img_rgb, cv2. COLOR_RGB2HSV)
img_rgb2= cv2.cvtColor(img_hsv, cv2.COLOR_HSV2RGB)
fig, axs= plt. subplots(1,3,figsize=(20,10))

axs[0].imshow(img_rgb)
axs[0].set_title('imagen original')
axs[1].imshow(img_hsv)
axs[1].set_title('imagen hsv')
axs[2].imshow(img_rgb)
axs[2].set_title('imagen rgb')
# Out:
# Text(0.5, 1.0, 'imagen rgb')

# %%
import cv2
import matplotlib.pyplot as plt

# Leer imagen en escala de grises
imagen = cv2.imread('maquiavelo.jpg', 0)

# Aplicar umbralización binaria e inversa
_, umbrellabinario = cv2.threshold(imagen, 127, 255, cv2.THRESH_BINARY)
_, umbrellabinarioinv = cv2.threshold(imagen, 127, 255, cv2.THRESH_BINARY_INV)

# Crear figura y subgráficos
plt.figure(figsize=(12, 4))  # Ajusta el tamaño de la figura

# Imagen original
plt.subplot(1, 3, 1)
plt.imshow(imagen, cmap='gray')
plt.title('Imagen Original')
plt.axis('off')

# Imagen binaria
plt.subplot(1, 3, 2)
plt.imshow(umbrellabinario, cmap='gray')
plt.title('Imagen Binaria')
plt.axis('off')

# Imagen binaria inversa
plt.subplot(1, 3, 3)
plt.imshow(umbrellabinarioinv, cmap='gray')
plt.title('Imagen Binaria Inversa')
plt.axis('off')

# Mostrar figura
plt.show()

# %% [markdown]
# RGB A YUV

# %%
import cv2
import matplotlib.pyplot as plt

imagen = cv2.imread('maquiavelo.jpg', )

img_rgb= cv2.cvtColor(cv2.imread('maquiavelo.jpg', cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB)
img_yub= cv2.cvtColor(img_rgb, cv2. COLOR_RGB2YUV)
img_rgb2= cv2.cvtColor(img_hsv, cv2.COLOR_YUV2RGB)
fig, axs= plt. subplots(1,3,figsize=(20,10))

plt.subplot(1, 3, 1)
plt.imshow(img_rgb)
plt.title('Imagen RGB')
plt.axis('off')

# Imagen binaria
plt.subplot(1, 3, 2)
plt.imshow(img_yub)
plt.title('Imagen RGB A YUV')
plt.axis('off')


plt.subplot(1, 3, 3)
plt.imshow(img_rgb2)
plt.title('Imagen YUV A RGB')
plt.axis('off')

plt.show()

# %% [markdown]
# FILTRO BAYER

# %%
import cv2
import matplotlib.pyplot as plt

# Cargar la imagen Bayer en escala de grises (asegúrate de tener la imagen "bayer_image.png")
bayer_image = cv2.imread("maquiavelo.jpg", cv2.IMREAD_GRAYSCALE)
if bayer_image is None:
    print("Error: No se pudo cargar la imagen.")
    exit()

# Convertir la imagen utilizando los diferentes patrones Bayer
img_BG = cv2.cvtColor(bayer_image, cv2.COLOR_BAYER_BG2RGB)
img_GB = cv2.cvtColor(bayer_image, cv2.COLOR_BAYER_GB2RGB)
img_RG = cv2.cvtColor(bayer_image, cv2.COLOR_BAYER_RG2RGB)
img_GR = cv2.cvtColor(bayer_image, cv2.COLOR_BAYER_GR2RGB)

# Configurar la figura con 4 subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Mostrar cada imagen en su respectivo subplot
axs[0, 0].imshow(img_BG)
axs[0, 0].set_title("Bayer BG2RGB")
axs[0, 0].axis("off")

axs[0, 1].imshow(img_GB)
axs[0, 1].set_title("Bayer GB2RGB")
axs[0, 1].axis("off")

axs[1, 0].imshow(img_RG)
axs[1, 0].set_title("Bayer RG2RGB")
axs[1, 0].axis("off")

axs[1, 1].imshow(img_GR)
axs[1, 1].set_title("Bayer GR2RGB")
axs[1, 1].axis("off")


plt.show()
